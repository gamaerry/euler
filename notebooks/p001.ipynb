# %% [markdown]
# # Primer intento:
# La primera intuición al abordar este problema es usar un ciclo o, en el caso de python, un generator expression:

# %%
sum(i for i in range(1000) if i % 3 == 0 or i % 5 == 0)
# Out:
# 233168

# %% [markdown]
# # Optimización:
# La IA recomienda usar la formula de la suma de la progresión aritmética:

# %%
def suma_aritmetica(n, limite):
    m = (limite - 1) // n # donde m es el numero de multiplos de n en [1,limite)
    return n * (m * (m + 1)) // 2

suma_aritmetica(3, 1000) + suma_aritmetica(5, 1000) - suma_aritmetica(15, 1000)
# Out:
# 233168
