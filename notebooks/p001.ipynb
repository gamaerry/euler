# %% [markdown]
# # Primer intento:
#
# La primera intuición al abordar este problema es usar un ciclo o, en el caso de python, un generator expression:

# %%
def primer_intento():
    return sum(i for i in range(1000) if i % 3 == 0 or i % 5 == 0)

primer_intento()
# Out:
# 233168

# %% [markdown]
# # Optimizacion:
#
# gemini recomienda usar la formula de la suma de la progresión aritmética:

# %%
def optimizacion():
    def suma_aritmetica(n, limite):
        m = (limite - 1) // n
        return n * (m * (m + 1)) // 2
    resultado = suma_aritmetica(3, 1000) + suma_aritmetica(5, 1000) - suma_aritmetica(15, 1000)
    return resultado

optimizacion()
# Out:
# 233168

# %% [markdown]
# # Comparacion:
#
# Esta celda compara ambos metodos en tiempo y memoria.

# %%
from lib.utils import comparar_metodos

comparar_metodos(primer_intento, optimizacion)
# Out:
# --- Primer intento ---
# Resultado: 233168
# Consistente: True
# Repeticiones por corrida: 1000
# Tiempo promedio:  49.3367 us
# Tiempo mediano:   48.6927 us
# Tiempo minimo:    47.9948 us
# Tiempo stdev:     1.6954 us  (CV: 3.4%)
# Memoria promedio: 1.1641 KB
# Memoria mediana:  1.1719 KB
# Memoria maxima:   1.2656 KB
# Memoria stdev:    95.5545 B
# Asignaciones (mediana): 2
#
# --- Optimizacion ---
# Resultado: 233168
# Consistente: True
# Repeticiones por corrida: 100000
# Tiempo promedio:  402.1958 ns
# Tiempo mediano:   402.4232 ns
# Tiempo minimo:    393.3026 ns
# Tiempo stdev:     5.4779 ns  (CV: 1.4%)
# Memoria promedio: 904.0000 B
# Memoria mediana:  912.0000 B
# Memoria maxima:   1008.0000 B
# Memoria stdev:    95.5545 B
# Asignaciones (mediana): 2
#
# === Comparacion directa ===
# Speedup en tiempo:    121.00x  (gana: Optimizacion)
# Ratio de memoria:     1.32x  (gana: Optimizacion)
# Ratio asignaciones:   1.00x  (gana: Primer intento, menos = mejor)
# {'Primer intento': {'resultado': 233168,
#   'consistente': True,
#   'tiempos': [4.903179400000002e-05,
#    4.7994789999999955e-05,
#    4.8341184999999955e-05,
#    4.835370099999992e-05,
#    4.830152500000029e-05,
#    5.02104710000002e-05,
#    5.3135930000000274e-05,
#    4.932407199999966e-05],
#   'memorias': [1.265625, 1.203125, 1.140625, 1.046875],
#   'asignaciones': [2, 2, 2, 2],
#   'repeticiones': 1000},
#  'Optimizacion': {'resultado': 233168,
#   'consistente': True,
#   'tiempos': [4.067812900000023e-07,
#    4.090431799999994e-07,
#    4.066032099999983e-07,
#    4.013160299999985e-07,
#    4.027461900000029e-07,
#    4.021001499999999e-07,
#    3.956739099999984e-07,
#    3.9330263000000087e-07],
#   'memorias': [0.984375, 0.921875, 0.859375, 0.765625],
#   'asignaciones': [2, 2, 2, 2],
#   'repeticiones': 100000}}
