# %% [markdown]
# # Primer intento:
#
# La primera intuición al abordar este problema es usar un ciclo o, en el caso de python, un generator expression:

# %%
def primer_intento():
    return sum(i for i in range(1000) if i % 3 == 0 or i % 5 == 0)

primer_intento()
# Out:
# 233168

# %% [markdown]
# # Optimizacion:
#
# gemini recomienda usar la formula de la suma de la progresión aritmética:

# %%
def optimizacion():
    def suma_aritmetica(n, limite):
        m = (limite - 1) // n
        return n * (m * (m + 1)) // 2
    resultado = suma_aritmetica(3, 1000) + suma_aritmetica(5, 1000) - suma_aritmetica(15, 1000)
    return resultado

optimizacion()
# Out:
# 233168

# %% [markdown]
# # Comparacion:
#
# Esta celda compara ambos metodos en tiempo y memoria.

# %%
from lib.utils import comparar_metodos

comparar_metodos(primer_intento, optimizacion)
# Out:
# --- Primer intento ---
# Resultado: 233168
# Consistente: True
# Repeticiones por corrida: 100
# Tiempo promedio: 5.068019e-05 s
# Tiempo mediano: 5.025312e-05 s
# Tiempo minimo: 4.875464e-05 s
# Memoria promedio: 0.37 KB
# Memoria mediana: 0.37 KB
# Memoria maxima: 0.37 KB
#
# --- Optimizacion ---
# Resultado: 233168
# Consistente: True
# Repeticiones por corrida: 100000
# Tiempo promedio: 4.007565e-07 s
# Tiempo mediano: 3.980602e-07 s
# Tiempo minimo: 3.941886e-07 s
# Memoria promedio: 0.16 KB
# Memoria mediana: 0.16 KB
# Memoria maxima: 0.16 KB
# {'Primer intento': {'resultado': 233168,
#   'consistente': True,
#   'tiempos': [5.043345999999893e-05,
#    5.127282999999983e-05,
#    4.910635999999968e-05,
#    4.8824489999998996e-05,
#    5.361968000000106e-05,
#    5.007278000000115e-05,
#    4.87546399999994e-05,
#    5.335727000000068e-05],
#   'memorias': [0.3671875, 0.3671875, 0.3671875, 0.3671875],
#   'repeticiones': 100},
#  'Optimizacion': {'resultado': 233168,
#   'consistente': True,
#   'tiempos': [3.943025899999997e-07,
#    3.9418856999999805e-07,
#    3.967152599999979e-07,
#    4.06305950000001e-07,
#    4.056598400000011e-07,
#    3.9855792e-07,
#    3.975625799999971e-07,
#    4.1275920999999994e-07],
#   'memorias': [0.1640625, 0.1640625, 0.1640625, 0.1640625],
#   'repeticiones': 100000}}
