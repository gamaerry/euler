# %% [markdown]
# # Primer intento:
#
# Algoritmo basado en los bloques fundamentales de los numeros del 1 al 20

# %%
def primer_intento():
    i = 32 # Desbloqueado el uso de prod(), lcm() y gcd() de math
    encontrado = False
    while True:
        for j in (9,5,7,11,13,16,17,19): 
            if i % j != 0:
                break
            else:
                encontrado = j == 19
        if encontrado:
            break
        else:
            i += 16 # el resultado deberia ser multiplo de 16
    return i

primer_intento()
# Out:
# 232792560

# %% [markdown]
# # Optimizacion:
#
# por definición de los bloques fundamentales, el mcm (lcm por sus siglas en inglés) es el producto de estos

# %%
from math import prod

def optimizacion():
      return 9*5*7*11*13*16*17*19

optimizacion()
# Out:
# 232792560

# %% [markdown]
# # Comparacion:
#
# Esta celda compara ambos metodos en tiempo y memoria.

# %%
from lib.utils import comparar_metodos

comparar_metodos(primer_intento, optimizacion)
# Out:
# --- Primer intento ---
# Resultado: 232792560
# Consistente: True
# Repeticiones por corrida: 1
# Tiempo promedio: 0.896944 s
# Tiempo mediano: 0.896516 s
# Tiempo minimo: 0.893499 s
# Memoria promedio: 0.00 KB
# Memoria mediana: 0.00 KB
# Memoria maxima: 0.00 KB
#
# --- Optimizacion ---
# Resultado: 232792560
# Consistente: True
# Repeticiones por corrida: 100000
# Tiempo promedio: 0.000000 s
# Tiempo mediano: 0.000000 s
# Tiempo minimo: 0.000000 s
# Memoria promedio: 0.00 KB
# Memoria mediana: 0.00 KB
# Memoria maxima: 0.00 KB
# {'Primer intento': {'resultado': 232792560,
#   'consistente': True,
#   'tiempos': [0.8961421629999995,
#    0.8985879990000001,
#    0.8934993670000004,
#    0.9006352339999992,
#    0.8962448720000005,
#    0.8967872740000011,
#    0.8936433920000013,
#    0.9000141849999999],
#   'memorias': [0.0, 0.0, 0.0, 0.0],
#   'repeticiones': 1},
#  'Optimizacion': {'resultado': 232792560,
#   'consistente': True,
#   'tiempos': [2.716503999998565e-08,
#    2.691784999999669e-08,
#    2.6663169999991966e-08,
#    2.6697169999998493e-08,
#    2.6658180000005417e-08,
#    2.6500300000016354e-08,
#    2.720619999998064e-08,
#    2.6938550000004112e-08],
#   'memorias': [0.0, 0.0, 0.0, 0.0],
#   'repeticiones': 100000}}
