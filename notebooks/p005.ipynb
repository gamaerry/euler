# %% [markdown]
# # Primer intento:
#
# Algoritmo basado en los bloques fundamentales de los numeros del 1 al 20

# %%
def primer_intento():
    i = 32 # Desbloqueado el uso de prod(), lcm() y gcd() de math
    encontrado = False
    while True:
        for j in (9,5,7,11,13,16,17,19): 
            if i % j != 0:
                break
            else:
                encontrado = j == 19
        if encontrado:
            break
        else:
            i += 16 # el resultado deberia ser multiplo de 16
    return i

primer_intento()
# Out:
# 232792560

# %% [markdown]
# # Optimizacion:
#
# por definición de los bloques fundamentales, el mcm (lcm por sus siglas en inglés) es el producto de estos

# %%
from math import prod

def optimizacion():
      return 9*5*7*11*13*16*17*19

optimizacion()
# Out:
# 232792560

# %% [markdown]
# # Comparacion:
#
# Esta celda compara ambos metodos en tiempo y memoria.

# %%
from lib.utils import comparar_metodos

comparar_metodos(primer_intento, optimizacion)
# Out:
# --- Primer intento ---
# Resultado: 232792560
# Consistente: True
# Repeticiones por corrida: 1
# Tiempo promedio:  897.2579 ms
# Tiempo mediano:   901.8757 ms
# Tiempo minimo:    881.5681 ms
# Tiempo stdev:     9.2216 ms  (CV: 1.0%)
# Memoria promedio: 1.1641 KB
# Memoria mediana:  1.1719 KB
# Memoria maxima:   1.2656 KB
# Memoria stdev:    95.5545 B
# Asignaciones (mediana): 2
#
# --- Optimizacion ---
# Resultado: 232792560
# Consistente: True
# Repeticiones por corrida: 100000
# Tiempo promedio:  26.5611 ns
# Tiempo mediano:   26.5570 ns
# Tiempo minimo:    26.5090 ns
# Tiempo stdev:     0.0414 ns  (CV: 0.2%)
# Memoria promedio: 904.0000 B
# Memoria mediana:  912.0000 B
# Memoria maxima:   1008.0000 B
# Memoria stdev:    95.5545 B
# Asignaciones (mediana): 2
#
# === Comparacion directa ===
# Speedup en tiempo:    33959994.21x  (gana: Optimizacion)
# Ratio de memoria:     1.32x  (gana: Optimizacion)
# Ratio asignaciones:   empate (2)
# {'Primer intento': {'resultado': 232792560,
#   'consistente': True,
#   'tiempos': [0.8943999709999995,
#    0.904308017,
#    0.9026288080000002,
#    0.8815681390000005,
#    0.8852846079999992,
#    0.9055507170000006,
#    0.9032006589999995,
#    0.901122663999999],
#   'memorias': [1.265625, 1.203125, 1.140625, 1.046875],
#   'asignaciones': [2, 2, 2, 2],
#   'repeticiones': 1},
#  'Optimizacion': {'resultado': 232792560,
#   'consistente': True,
#   'tiempos': [2.6641030000007504e-08,
#    2.6552070000001037e-08,
#    2.652881999999579e-08,
#    2.6569310000006397e-08,
#    2.650900999999095e-08,
#    2.656194000000056e-08,
#    2.653408000000468e-08,
#    2.6592440000001716e-08],
#   'memorias': [0.984375, 0.921875, 0.859375, 0.765625],
#   'asignaciones': [2, 2, 2, 2],
#   'repeticiones': 100000}}
