# %%
n = 100

# %% [markdown]
# # Primer intento:
#
# uso directo de generator expressions

# %%
def primer_intento():
    return sum(i for i in range(n+1))**2 - sum(i**2 for i in range(n+1))

primer_intento()
# Out:
# 25164150

# %% [markdown]
# # Optimizacion:
#
# chatgpt recomienda sustituir ambas sumas por sus formulas cerradas, evitando por completo la iteracion:

# %%
def optimizacion():
    suma = n * (n + 1) // 2
    suma_cuadrados = n * (n + 1) * (2 * n + 1) // 6
    return suma**2 - suma_cuadrados

optimizacion()
# Out:
# 25164150

# %% [markdown]
# # Comparacion:
#
# Esta celda compara ambos metodos en tiempo y memoria.

# %%
from lib.utils import comparar_metodos

comparar_metodos(primer_intento, optimizacion)
# Out:
# --- Primer intento ---
# Resultado: 25164150
# Consistente: True
# Repeticiones por corrida: 1000
# Tiempo promedio: 7.174326e-06 s
# Tiempo mediano: 7.192276e-06 s
# Tiempo minimo: 6.839472e-06 s
# Memoria promedio: 0.37 KB
# Memoria mediana: 0.37 KB
# Memoria maxima: 0.37 KB
#
# --- Optimizacion ---
# Resultado: 25164150
# Consistente: True
# Repeticiones por corrida: 100000
# Tiempo promedio: 1.881247e-07 s
# Tiempo mediano: 1.877816e-07 s
# Tiempo minimo: 1.841040e-07 s
# Memoria promedio: 0.000000e+00 KB
# Memoria mediana: 0.000000e+00 KB
# Memoria maxima: 0.000000e+00 KB
# {'Primer intento': {'resultado': 25164150,
#   'consistente': True,
#   'tiempos': [7.185820999999981e-06,
#    7.344285000000062e-06,
#    6.839472000000013e-06,
#    7.380570000000031e-06,
#    6.9231040000001795e-06,
#    7.46714599999998e-06,
#    7.0554800000000025e-06,
#    7.198731999999986e-06],
#   'memorias': [0.3671875, 0.3671875, 0.3671875, 0.3671875],
#   'repeticiones': 1000},
#  'Optimizacion': {'resultado': 25164150,
#   'consistente': True,
#   'tiempos': [1.934007900000001e-07,
#    1.9117580000000077e-07,
#    1.9008106000000024e-07,
#    1.8820242999999958e-07,
#    1.8410397000000023e-07,
#    1.865047100000039e-07,
#    1.8416833000000298e-07,
#    1.8736072999999908e-07],
#   'memorias': [0.0, 0.0, 0.0, 0.0],
#   'repeticiones': 100000}}
