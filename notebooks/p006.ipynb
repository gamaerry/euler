# %%
n = 100

# %% [markdown]
# # Primer intento:
#
# uso directo de generator expressions

# %%
def primer_intento():
    return sum(i for i in range(n+1))**2 - sum(i**2 for i in range(n+1))

primer_intento()
# Out:
# 25164150

# %% [markdown]
# # Optimizacion:
#
# chatgpt recomienda sustituir ambas sumas por sus formulas cerradas, evitando por completo la iteracion:

# %%
def optimizacion():
    suma = n * (n + 1) // 2
    suma_cuadrados = n * (n + 1) * (2 * n + 1) // 6
    return suma**2 - suma_cuadrados

optimizacion()
# Out:
# 25164150

# %% [markdown]
# # Comparacion:
#
# Esta celda compara ambos metodos en tiempo y memoria.

# %%
from lib.utils import comparar_metodos

comparar_metodos(primer_intento, optimizacion)
# Out:
# --- Primer intento ---
# Resultado: 25164150
# Consistente: True
# Repeticiones por corrida: 1000
# Tiempo promedio:  7.0896 us
# Tiempo mediano:   7.0744 us
# Tiempo minimo:    6.8117 us
# Tiempo stdev:     171.0584 ns  (CV: 2.4%)
# Memoria promedio: 1.1641 KB
# Memoria mediana:  1.1719 KB
# Memoria maxima:   1.2656 KB
# Memoria stdev:    95.5545 B
# Asignaciones (mediana): 2
#
# --- Optimizacion ---
# Resultado: 25164150
# Consistente: True
# Repeticiones por corrida: 100000
# Tiempo promedio:  177.9298 ns
# Tiempo mediano:   177.6072 ns
# Tiempo minimo:    176.5679 ns
# Tiempo stdev:     1.2822 ns  (CV: 0.7%)
# Memoria promedio: 904.0000 B
# Memoria mediana:  912.0000 B
# Memoria maxima:   1008.0000 B
# Memoria stdev:    95.5545 B
# Asignaciones (mediana): 2
#
# === Comparacion directa ===
# Speedup en tiempo:    39.83x  (gana: Optimizacion)
# Ratio de memoria:     1.32x  (gana: Optimizacion)
# Ratio asignaciones:   empate (2)
# {'Primer intento': {'resultado': 25164150,
# ...
